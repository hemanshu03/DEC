# %% [markdown]
# # Read Data from csv file and create dataframe

# %%
import pandas as pd
#creating a dataframe
df=pd.read_csv("/content/crop_production.csv")

#print the dataframe
df
# Out:
#                         State_Name District_Name  Crop_Year       Season  \
# 0      Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 1      Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 2      Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 3      Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 4      Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# ...                            ...           ...        ...          ...
# 15826                        Assam       DHEMAJI     2010.0  Rabi
# 15827                        Assam       DHEMAJI     2010.0  Rabi
# 15828                        Assam       DHEMAJI     2010.0  Rabi
# 15829                        Assam       DHEMAJI     2010.0  Rabi
# 15830                        Assam           NaN        NaN          NaN
#
#                         Crop     Area  Production
# 0                   Arecanut   1254.0      2000.0
# ...

# %% [markdown]
# # head() function returns first five rows from the dataframe

# %%
df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %% [markdown]
# # # tail() function returns last five rows from the dataframe

# %%
df.tail()
# Out:
#       State_Name District_Name  Crop_Year       Season                   Crop  \
# 15826      Assam       DHEMAJI     2010.0  Rabi                        Masoor
# 15827      Assam       DHEMAJI     2010.0  Rabi             Moong(Green Gram)
# 15828      Assam       DHEMAJI     2010.0  Rabi         Peas & beans (Pulses)
# 15829      Assam       DHEMAJI     2010.0  Rabi             Rapeseed &Mustard
# 15830      Assam           NaN        NaN          NaN                    NaN
#
#           Area  Production
# 15826     92.0        38.0
# 15827    229.0       128.0
# 15828    474.0       301.0
# 15829  16800.0      8214.0
# 15830      NaN         NaN

# %%
df.head(10)
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 5  Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 6  Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 7  Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 8  Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 9  Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
#
#                   Crop     Area  Production
# 0             Arecanut   1254.0      2000.0
# 1  Other Kharif pulses      2.0         1.0
# 2                 Rice    102.0       321.0
# 3               Banana    176.0       641.0
# ...

# %%
df.tail(10)
# Out:
#       State_Name District_Name  Crop_Year       Season                   Crop  \
# 15821      Assam       DHEMAJI     2010.0  Kharif               Small millets
# 15822      Assam       DHEMAJI     2010.0  Rabi                      Arecanut
# 15823      Assam       DHEMAJI     2010.0  Rabi                        Banana
# 15824      Assam       DHEMAJI     2010.0  Rabi                          Gram
# 15825      Assam       DHEMAJI     2010.0  Rabi                       Linseed
# 15826      Assam       DHEMAJI     2010.0  Rabi                        Masoor
# 15827      Assam       DHEMAJI     2010.0  Rabi             Moong(Green Gram)
# 15828      Assam       DHEMAJI     2010.0  Rabi         Peas & beans (Pulses)
# 15829      Assam       DHEMAJI     2010.0  Rabi             Rapeseed &Mustard
# 15830      Assam           NaN        NaN          NaN                    NaN
#
#           Area  Production
# 15821     14.0        10.0
# 15822    960.0       747.0
# ...

# %% [markdown]
# # Returns data types of columns

# %%
df.dtypes
# Out:
# State_Name        object
# District_Name     object
# Crop_Year        float64
# Season            object
# Crop              object
# Area             float64
# Production       float64
# dtype: object

# %% [markdown]
# # Returns minimum value from the columns

# %%
df.min()
# Out:
# <ipython-input-14-c3612c624a3f>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.min()
# State_Name    Andaman and Nicobar Islands
# Crop_Year                          1997.0
# Area                                  0.2
# Production                            0.0
# dtype: object

# %% [markdown]
# #Returns maximum value from the columns

# %%
df.max()
# Out:
# <ipython-input-15-4c1ddf8920ff>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()
# State_Name          Assam
# Crop_Year          2014.0
# Area             877029.0
# Production    780162000.0
# dtype: object

# %% [markdown]
# # calculates mean value (like average value)

# %%
df.mean()
# Out:
# <ipython-input-16-c61f0c8f89b5>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Crop_Year     2.006075e+03
# Area          9.677252e+03
# Production    1.168658e+06
# dtype: float64

# %% [markdown]
# # calculates median value (it is middle value from sorted data)

# %%
df.median()
# Out:
# <ipython-input-20-6d467abf240d>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Crop_Year     2006.0
# Area           727.0
# Production    1251.0
# dtype: float64

# %% [markdown]
# # calculates the mode value
# - A mode is defined as the value that has a higher frequency in a given set of values.
# - It is the value that appears the most number of times.

# %%
df.mode()
# Out:
#        State_Name District_Name  Crop_Year       Season  Crop  Area  \
# 0  Andhra Pradesh       KURNOOL     2013.0  Kharif       Rice   2.0
#
#    Production
# 0         1.0

# %% [markdown]
# # Calculates the variance
# Variance measures how far each number in the set is from the mean (average),and thus from every other number in the set.

# %%
df.var()
# Out:
# <ipython-input-18-28ded241fd7c>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# Crop_Year     2.627073e+01
# Area          1.424014e+09
# Production    4.768099e+14
# dtype: float64

# %% [markdown]
# # Calculates the standard deviation
# Standard Deviation is a measure which shows how much variation (such as spread, dispersion, spread,) from the mean exists

# %%
df.std()
# Out:
# <ipython-input-19-ce97bb7eaef8>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# Crop_Year     5.125498e+00
# Area          3.773610e+04
# Production    2.183598e+07
# dtype: float64

# %% [markdown]
# # Counts the non empty values from each column

# %%
df.count()
# Out:
# State_Name       15831
# District_Name    15830
# Crop_Year        15830
# Season           15830
# Crop             15830
# Area             15830
# Production       15760
# dtype: int64

# %% [markdown]
# # describe() method returns description of the data in the DataFrame.
# - count - The number of not-empty values.
# - mean - The average (mean) value.
# - std - The standard deviation.
# - min - the minimum value.
# - 25% - The 25% percentile*.
# - 50% - The 50% percentile*.
# - 75% - The 75% percentile*.
# - max - the maximum value.
#
# **Percentile meaning: how many of the values are less than the given percentile.**

# %%
df.describe()
# Out:
#           Crop_Year           Area    Production
# count  15830.000000   15830.000000  1.576000e+04
# mean    2006.075237    9677.251678  1.168658e+06
# std        5.125498   37736.103854  2.183598e+07
# min     1997.000000       0.200000  0.000000e+00
# 25%     2002.000000     126.000000  1.957500e+02
# 50%     2006.000000     727.000000  1.251000e+03
# 75%     2011.000000    4000.000000  8.794000e+03
# max     2014.000000  877029.000000  7.801620e+08

# %%
import networkx as nx
import matplotlib.pyplot as plt
G=nx.Graph()
G.add_nodes_from([i for i in range(10)])
def create_graph(n):
  while(len(G.edges())<n):
    u=random.choice(list(G.nodes()))
    v=random.choice(list(G.nodes()))
    if u!=v and G.has_edge(u,v)==0:
      G.add_edge(u,v)
nx.draw(G,with_labels=True)
plt.show()
